# %%
import os
from openai import OpenAI
from pydantic import BaseModel, Field, conlist
import time
import numpy as np
from numpy.linalg import norm
from scipy.interpolate import UnivariateSpline
from matplotlib import pyplot as plt
import re
from IPython.display import clear_output
import sys
from rake_nltk import Rake
from pylatexenc.latex2text import LatexNodes2Text
import nltk

client = OpenAI(api_key = os.environ["OPENAI_API_KEY"])

class gen_format(BaseModel):
    Question: conlist(str, min_length=5, max_length=5) = Field(description="A list of five questions that could be answered by the given answer")
    
class rag_format(BaseModel):
    Ranked_Relevant_Information: list[str] = Field(description="The ranked list of information relevant to the query, with no paraphrasing or changing of the text from the files.")

def preprocess_text(text):
    # Replace decimals/commas in numbers with an underscore and replace hyphens with underscores, generally (except for negative numbers).
    #It is only these cases that the sentence tokenizer in Rake doesn't seem to handle well
    text = re.sub(r'(\d+)\.(\d+)', r'\1_\2', text)
    text = re.sub(r'(\d+)\,(\d+)', r'\1\2', text)
    #cursive l in text is formatted strangely in cmbagent output
    text = text.replace("`", "l")
    # Pattern explanation:
    # (?<!\s)-(?!\d) - matches hyphens not preceded by whitespace or followed by digit
    # | - OR
    # (?<=\s)-(?=\D) - matches hyphens preceded by whitespace and followed by non-digit
    text = re.sub(r'(?<!\s)-(?!\d)|(?<=\s)-(?=\D)', '_', text)
    return text
    
def embedding_answers(answer, ideal, custom_stopwords, english_words) -> str:
    #tell Rake to leave logical comparatives alone
    r = Rake(stopwords=custom_stopwords)
    # Extraction given the text.
    text1=preprocess_text(answer)
    #ideal is formatted using latex for CMBagent
    ideal=LatexNodes2Text().latex_to_text(ideal)
    text2=preprocess_text(ideal)
    r.extract_keywords_from_text(text1)
    key_phrases1=r.get_ranked_phrases()
    r.extract_keywords_from_text(text2)
    key_phrases2=r.get_ranked_phrases()
    print(key_phrases1)
    print(key_phrases2)
    result_1=[]
    for string_ideal in key_phrases2:
        #check for "names" that need to be matched exactly
        #checks that string_ideal is one word with at least one letter and that is not in english
        if (not (" " in string_ideal)) and (any(char.isalpha() for char in string_ideal)) and (not (string_ideal in english_words)):
            #if this word does exist in the answer...
            string_ideal=string_ideal.replace("_", "")
            #sort out odd formatting issues surrounding underscores in "names"
            if (string_ideal in text1.lower()):
                #we have a match!
                result_1.append(1)
            else:
                #if not, no match, therefore "incorrect"
                result_1.append(0.7)
        else:
            max_cos=0
            check=0
            for string_gen in key_phrases1:
                if (string_ideal==string_gen and check==0):
                    max_cos=1
                    result_1.append(max_cos)
                    check=1
            if (max_cos!=1):
                resp1 = client.embeddings.create(
                    input=string_ideal,
                    model="text-embedding-ada-002",
                    encoding_format= "float",
                )
                for string_gen in key_phrases1:
                    resp2 = client.embeddings.create(
                        input=string_gen,
                        model="text-embedding-ada-002",
                        encoding_format= "float",
                    )
                    a=np.array(resp1.data[0].embedding)
                    b=np.array(resp2.data[0].embedding)
                    cos=np.dot(a,b)/(norm(a)*norm(b))
                    if (cos>max_cos):
                        max_cos=cos
                result_1.append(max_cos)
    return np.array(result_1)

def embedding_questions(question, answer, question_model) -> str:
    og_question = client.embeddings.create(
        input=question,
        model="text-embedding-ada-002",
        encoding_format= "float",
    )
    gen_message="""
    You are a question generating agent. Your task is to generate a list of questions for the given answer.
    """
    gen_assistant = client.beta.assistants.create(
        name="gen_test",
        instructions=gen_message,
        model=question_model, 
        temperature = 0.0,
        top_p = 0.2,
        response_format= {
            "type": "json_schema",
            "json_schema": {
                "name": "answer",
                "schema": gen_format.model_json_schema()
            },
        }
    )
    
    thread = client.beta.threads.create(
                    messages=[],
                )
    
    parsed = client.beta.threads.messages.create(
                    thread_id=thread.id,
                    content=answer,
                    role='user',
                )
    
    run = client.beta.threads.runs.create(
        thread_id=thread.id,
        assistant_id=gen_assistant.id,
        # pass the latest system message as instructions
        instructions=gen_message,
    )
    run = client.beta.threads.runs.retrieve(run.id, thread_id=thread.id)
    while run.status!="completed":
        run = client.beta.threads.runs.retrieve(run.id, thread_id=thread.id)
    response_messages = client.beta.threads.messages.list(thread.id, order="asc")
    for message in response_messages.data:
        for content in message.content:
            output=content.text.value
            if output.startswith("{"):
                data=json.loads(output)
                generated=data["Question"]
    client.beta.assistants.delete(assistant_id=gen_assistant.id)
    result=[]
    for gen_question in generated:
        gen_question_vector = client.embeddings.create(
            input=gen_question,
            model="text-embedding-ada-002",
            encoding_format= "float",
        )
        a=np.array(gen_question_vector.data[0].embedding)
        b=np.array(og_question.data[0].embedding)
        result.append(np.dot(a, b)/(norm(a)*norm(b)))
    return result
    
def embedding_search(vector_store, question, answer, search_model) -> str:
    rag_message="""You are a retrieval agent tasked with performing file searches to find information for the purpose of providing answers.
        Find pieces of information that will be directly relevant for answering the query and rank these pieces of information from most relevant to least relevant.
        You must quote the passages from the files directly. Do not paraphrase or change the text in any way.
        Do not add anything else to the passage quotations, including sources and filenames.
        If no information is relevant, you must return a single piece of information, where you state "No information found".
        Ideally, these pieces of information will be sentences, phrases, data points or sets of data points, but you have limited flexiblility to include other pieces of information if you think they are appropriate.
        
        You must use tool call (i.e., file search).
        
        You know about the content of the code-base.
        """
    rag_assistant = client.beta.assistants.create(
        name="rag_test",
        instructions=rag_message,
        tools=[
            {"type": "file_search",
                "file_search":{
                    'max_num_results': 10,
                    "ranking_options": {
                        "ranker": "auto",
                        "score_threshold": 0.6
                    }
                }
            }
        ],
        tool_resources={"file_search": {"vector_store_ids":[vector_store.id]}},
        model=search_model, 
        temperature = 0,
        top_p = 0.2,
        response_format= {
            "type": "json_schema",
            "json_schema": {
                "name": "answer",
                "schema": rag_format.model_json_schema()
            },
        }
    )
    thread = client.beta.threads.create(
                    messages=[],
                )
    
    parsed = client.beta.threads.messages.create(
                    thread_id=thread.id,
                    content=question,
                    role='user',
                )
    
    run = client.beta.threads.runs.create(
        thread_id=thread.id,
        assistant_id=rag_assistant.id,
        # pass the latest system message as instructions
        instructions=rag_message,
    )
    run = client.beta.threads.runs.retrieve(run.id, thread_id=thread.id)
    while run.status!="completed":
        run = client.beta.threads.runs.retrieve(run.id, thread_id=thread.id)
    response_messages = client.beta.threads.messages.list(thread.id, order="asc")
    for message in response_messages.data:
        for content in message.content:
            output=content.text.value
            if output.startswith("{"):
                data=json.loads(output)
                try:
                    information=data["Ranked_Relevant_Information"]
                except:
                    information=data["Ranked Relevant Information"]
    if ("information" in locals()):
        #uncomment for hallucination guarding
        """run_steps = client.beta.threads.runs.steps.list(
            thread_id=thread.id,
            run_id=run.id
        )
        j=0
        for step in run_steps.data:
            #wait until the runs.steps.list has finished
            while step.status!="completed":
                run_steps = client.beta.threads.runs.steps.list(
                    thread_id=thread.id,
                    run_id=run.id
                )
            if (j!=0):
                retrieved_step = client.beta.threads.runs.steps.retrieve(
                    thread_id=step.thread_id,
                    run_id=run.id,
                    step_id=step.id,
                    include=["step_details.tool_calls[*].file_search.results[*].content"]
                )
                #check for hallucinations and flag all "offending text" from the passed information list
                information=hallucination_check(retrieved_step, information, question, 20)
            j+=1
        """
        pass
    else:
        information=["No information."]
    answer_resp = client.embeddings.create(
        input=answer,
        model="text-embedding-ada-002",
        encoding_format= "float",
    )
    results=[]
    for i in range(len(information)):
        info_resp = client.embeddings.create(
            input=information[i],
            model="text-embedding-ada-002",
            encoding_format= "float",
        )
        a=np.array(info_resp.data[0].embedding)
        b=np.array(answer_resp.data[0].embedding)
        results.append(np.dot(a, b)/(norm(a)*norm(b)))
    i=0
    #add is binary True/False
    add=1
    my_diff=0
    mean_score=[]
    for score in results:
        if (i!=0):
            my_diff=np.absolute(score-store)
            if (i==1):
                ref_diff=my_diff
            if (my_diff>=2*ref_diff):
                add=0
        if (add==1):
            mean_score.append(score)
            store=score
            i+=1
    return mean_score
def hallucination_check(retrieved_step, information, question, char_match):
    raw_information=""
    for result in retrieved_step.step_details.tool_calls[0].file_search.results:
        raw_information=raw_information+result.content[0].text
    #regex expression to remove all references from the text before "cleaning".
    raw_information = re.sub(r"\(\d+\)|\[\d+\]|\(.*Fig.*\)|\(.*Table.*\)", "", raw_information)
    file_information=''.join(ch for ch in raw_information if ch.isalnum())
    for i in range(len(information)):
        verify=information[i].split("...")
        for split in verify:
            filtered_information=''.join(ch for ch in split if ch.isalnum())
            if not (filtered_information in file_information):
                clear_output(wait=True)
                print("AI is answering this question:\n"+question)
                print("AI understood:\n"+split)
                length=len(filtered_information)
                if length < char_match:
                    char_match = length
                index=file_information.find(filtered_information[:char_match])
                if (index!=-1):
                    print("The file contained:\n"+file_information[index:index+length])
                else:
                    index=file_information.find(filtered_information[length-char_match:])
                    if (index!=-1):
                        print("The file contained:\n"+file_information[index-length+char_match:index+char_match])
                    else:
                        print("The file contained:\n"+raw_information)
                print("Waiting for user input...")
                print("Correct the potential hallucination. If the AI is correct, type 'y'. If information given by the AI is not in the file segment, type 'n'.", end='', flush=True)
                user=input()
                print("User entered:", user)
                if (user!='y'):
                    print("The file contained:\n"+raw_information)
                    print("Correct the potential hallucination. If the AI is correct, type 'y'. If no information from these chunks is relevant, type 'n'. Otherwise, input what the information should be.", end='', flush=True)
                    user=input()
                    if (user!='y'):
                        if(user=='n'):
                            split="Null information."
                        else:
                            split=user
        information[i]=""
        for split in verify:
            information[i]=information[i]+"..."+split
        information[i]=information[i][3:]
    return information

# %%
import pandas as pd

nltk.download('stopwords')
nltk.download('words')
english_words = set(nltk.corpus.words.words())

custom_stopwords = set(nltk.corpus.stopwords.words('english')) - {"no", "not", "than", "more", "same", "before", "after", "now", "then", "above", "below", "over", "under", "like", "other", "such", "few", "most", "some", "between"}  # Keep logical comparatives- important for RAG analysis 

assistant_data = "/home/adrian/Documents/University Work/Part III Project/cmbagent_dataset/Source_Papers"
lit = pd.read_csv('../cmbagent_dataset/cmbagent_dataset.csv')
question=[]
ideal=[]
for i in range(lit.shape[0]):
    question.append(lit.loc[i, "question"])
    ideal.append(lit.loc[i, "ideal"])
#extract answer from these agent and ideal from LitQA2
with open("output_cmbagent.txt", 'r', encoding='utf-8') as file:
    file_content = file.read()
spaces=0
tab=0
i=0
answer=[]
#ideal=[]
for char in file_content:
    if (spaces==2 and char != "\t" and tab==0):
        answer[i]+=char
    elif (char =="\t"):
        spaces=0
        #ideal.append("")
        tab+=1
    elif (char != "\n" and tab==1):
        #ideal[i]+=char
        pass
    elif (char == "\n" and tab==1):
        i+=1
        tab=0
    if (char == " " and spaces<2 and tab==0):
        spaces+=1
        if (spaces==2):
            answer.append("")
for i in range(len(answer)):
    answer[i]=" ".join(word for word in answer[i].split() if (".pdf" not in word) and ("†" not in word))
# Out:
# [nltk_data] Downloading package stopwords to /home/adrian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /home/adrian/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
answer_store=[]
print("Embedding Answers")
for i in range(len(answer)):
    print(i/len(answer)*100, end="")
    print("\r", end="")
    answer_store.append(embedding_answers(answer[i], ideal[i], custom_stopwords, english_words))
    print(answer[i]+"\n"+ideal[i]+"\n"+str(answer_store[i])+" "+str(np.mean(answer_store[i]))+"\n")
# Out:
# Embedding Answers
# ['including act data enhances', 'reconstructed recombination histories', 'no significant departures', 'method examines deviations', 'standard recombination history', 'standard recombination history', 'planck 2018 analysis', 'standard scenario', 'standard prediction', 'principal_component analysis', 'z ),', 'semi_blind eigen_analysis', 'results indicate', 'high redshifts', 'free_electron fraction', 'free_electron fraction', 'xe', 'using', 'tested', 'particularly', 'form', 'constraints', 'consistent', 'additionally']
# ['semi_blind eigen_analysis', 'principal_component analysis', 'often referred']
# The standard recombination history is tested in the Planck 2018 analysis by using a semi-blind eigen-analysis, which is a form of principal-component analysis. This method examines deviations of the free-electron fraction, xe(z), from the standard recombination history. The results indicate that there are no significant departures from the standard prediction, and the reconstructed recombination histories are consistent with the standard scenario. Additionally, including ACT data enhances the constraints on the free-electron fraction, particularly at high redshifts.
# semi-blind eigen-analysis (often referred to as a principal-component analysis)
# [1.         1.         0.80201622] 0.9340054067679407
#
# ['correction addressed temperature_to_polarization leakage caused', 'utilized polarized beam matrices computed', '** effective polarization efficiencies **:', '** beam_leakage correction **:', 'frequency polarization power spectra', 'best_fit base_λcdm model based', 'effective polarization efficiencies', 'polarization spectra included', 'best_fit λcdm cosmology', 'fiducial theoretical spectra', 'fiducial spectra derived', '2018 planck analysis', 'correction template', 'beam mismatch', 'analysis estimated', 'temperature data', 'sroll maps', 'quickpol code', 'corrections implemented', 'based', 'comparing', '2', '1']
# ['beam leakage correction']
# In the 2018 Planck analysis, corrections implemented in the polarization spectra included:1. **Beam-leakage correction**: This correction addressed temperature-to-polarization leakage caused by beam mismatch. It utilized polarized beam matrices computed with the QuickPol code, and the correction template was based on fiducial theoretical spectra from the best-fit ΛCDM cosmology.2. **Effective polarization efficiencies**: The analysis estimated the effective polarization efficiencies of the SRoll maps by comparing the frequency polarization power spectra to fiducial spectra derived from the best-fit base-ΛCDM model based on temperature data.
# Beam leakage correction
# [0.8937187] 0.8937187005442984
#
# ['reduce potential systematic biases arising', '143 × 217 spectrum', 'planck 2018 analysis', 'camspec temperature likelihood', 'multipole cuts applied', 'minimum cuts', 'specifically imposed', 'galactic dust', 'lmin', 'lmax', 'frequencies', '500l', '2500l']
# ['lmin', 'lmax', '500', '2500']
# For the 143 × 217 spectrum in the Camspec temperature likelihood for the Planck 2018 analysis, the multipole cuts applied are `min = 500` and `max = 2500`. These minimum cuts are specifically imposed to reduce potential systematic biases arising from Galactic dust at these frequencies.
# lmin=500, lmax=2500
# [1.         1.         0.86842698 0.91095366] 0.9448451601975538
#
# ['apodized camspec polarization mask', 'planck 2018 analysis', 'f w sky', 'effective sky_fraction', '47_7 %.']
# ['47_70']
# The effective sky-fraction of the apodized Camspec polarization mask for the Planck 2018 analysis is f W sky = 47.7 %.
# 47.70%
# [0.89326534] 0.8932653444185626
#
# ['beam window functions', 'baseline plik likelihood', 'approximately 0_1', '2018 spectra', 'small', 'l', 'impact', '2000']
# ['approximately 0_1']
# The impact of beam window functions on the 2018 spectra in the baseline Plik likelihood is small, approximately 0.1% at ` = 2000.
# approximately 0.1% at l=2000
# [1] 1.0
#
# ['1_04097 ± 0_00046', 'planck tt', 'lowe analysis', 'confidence level', 'acoustic scale', '100θ ∗', 'given', 'constraint', 'cl', '68', '2018']
# ['1_04097 ± 0_00046']
# The 68% confidence level (CL) constraint on the acoustic scale from the Planck TT+lowE analysis in 2018 is given as 100θ∗ = 1.04097 ± 0.00046.
# 1.04097\pm0.00046
# [1] 1.0
#
# ['× 10 − 9', '0_031 − 0_034', 'planck 2018', 'confidence level', '1_sigma constraint', 'tt', 'te', 'lowe', 'ee', '68', '2_101']
# ['0_034 )× 10 ^- 9', '2_101 ^+ 0_031_']
# The 1-sigma constraint on As with TT, TE, EE + lowE from Planck 2018 is As = (2.101 +0.031 −0.034) × 10−9 at a 68% confidence level.
# (2.101^{+0.031}_{-0.034})\times 10^{-9}
# [0.91355124 0.91120204] 0.9123766393661616
#
# ['large λcdm lensing amplitudes still yield', 'now slightly more significant', 'may suggest new physics', 'large_scale compensated isocurvature modes', 'after removing low multipoles', 'more lensing smoothing than', 'high_l temperature likelihood indicates', 'high_l cmb fluctuation amplitude', '2018 low_l likelihood', 'lensing smoothing shape', 'smoothing effect observed', 'planck collaboration int', 'planck 2018 analysis', 'one proposed explanation', 'cmb spectra alone', 'lower optical depth', 'alters theoretical predictions', 'unity within 1σ', 'smoothed data residuals', 'small upward shift', '30 ), a_l', 'lower τ leads', 'lensing amplitude', 'lensing reconstruction', 'λcdm model', 'λcdm model', 'lower amplitude', 'statistical fluctuation', 'cmb peaks', 'theoretical expectations', 'smoothing consistent', 'temperature data', 'visually evident', 'several factors', 'scalar perturbations', 'range 1100', 'previous findings', 'previous analyses', 'potentially mimicking', 'polarization efficiencies', 'polarization data', 'over half', 'oscillatory residual', 'not merely', 'beam leakage', 'additional contributions', '2σ tension', '2000 aligns', 'larger a_l', 'a_l deviating', 'a_l compared', 'notable preference', 'apparent preference', 'also attributed', 'temperature', 'within', 'shift', 'data', 'a_l', 'a_l', 'a_l', 'τ', 'τ', 'preference', 'preference', 'consistent', 'attributed', 'ω_mσ8', 'value', 'tt', 'terms', 'temperature_polarization', 'presence', 'pcp15', 'pcp13', 'necessitating', 'moreover', 'modeling', 'match', 'maps', 'maintain', 'li', 'l', 'l', 'however', 'firstly', 'explained', 'discussed', 'considering', 'changes', 'changes', 'allowed', 'a_s', '40', '2017', '2015', '1', '1']
# ['lower optical depth', '2018 low_l likelihood', 'small upward shift', 'over half', 'beam leakage', 'polarization efficiencies', 'shift', 'polarization', 'τ', 'temperature', 'modelling', 'maps', 'explained', 'explained', 'changes', 'changes', 'a_l', 'a_l']
# The apparent preference for A_L deviating from theoretical expectations in the Planck 2018 analysis can be attributed to several factors. Firstly, within the ΛCDM model, there is a notable preference for A_L > 1, which has been discussed in previous analyses (PCP13, PCP15, and Planck Collaboration Int. LI, 2017) and is now slightly more significant. In terms of temperature data, over half of the small upward shift in A_L compared to 2015 is explained by a lower optical depth (τ) from the 2018 low-` likelihood. A lower τ leads to a lower amplitude of scalar perturbations (A_s) to match the high-` CMB fluctuation amplitude, necessitating a larger A_L to maintain the lensing amplitude and smoothing consistent with previous findings.In polarization data, about 40% of the shift in A_L is also attributed to changes in τ, with additional contributions from changes in maps, modeling for beam leakage, and polarization efficiencies. The high-` temperature likelihood indicates a preference for more lensing smoothing than what is allowed by the ΛCDM model, which is visually evident in the smoothed data residuals. This oscillatory residual in the range 1100 < ` < 2000 aligns with the lensing smoothing shape.Moreover, when considering the CMB spectra alone, after removing low multipoles (` < 30), A_L from temperature and temperature-polarization (TT) data is consistent with unity within 1σ. However, the large ΛCDM lensing amplitudes still yield a value of Ω_mσ8 that is in 2σ tension with lensing reconstruction. If the preference for A_L > 1 is not merely a statistical fluctuation, it may suggest new physics that alters theoretical predictions, potentially mimicking the smoothing effect observed in the CMB peaks. One proposed explanation for this is the presence of large-scale compensated isocurvature modes.
# In temperature, over half of the small upward shift in A_L is explained by the lower optical depth from the 2018 low-l likelihood, In polarization, the shift in A_L is explained by changes in \tau, with changes in the maps, modelling for beam leakage, and polarization efficiencies.
# [1.         1.         1.         1.         1.         1.
#  1.         0.92535172 1.         1.         0.7        1.
#  1.         1.         1.         1.         1.         1.        ] 0.9791862066546595
#
# ['indicating no significant inconsistency between', 'sptpol te spectrum compared', 'planck 2018 best_fit parameters', 'two sets', 'parameters', 'pte', 'probability', 'exceed', '0_64']
# ['0_64']
# The PTE (probability to exceed) for the SPTpol TE spectrum compared to the Planck 2018 best-fit parameters is 0.64, indicating no significant inconsistency between the two sets of parameters.
# 0.64
# [1] 1.0
#
# ['1 /( 1 − b', 'weak gravitational lensing estimates', '1 − b ).', 'planck cluster counts relies', '1 − b', '1 − b', '1 − b', 'x_ray cluster masses', 'various constraints provided', '0_99 ± 0_19', '0_78 ± 0_08', '0_69 ± 0_07', '0_62 ± 0_03', 'x_ray derived masses', 'mass bias parameter', 'hydrostatic mass bias', 'planck analysis', 'hydrostatic equilibrium', 'expected bias', 'derived constraint', 'bias factor', 'systematic errors', 'low due', 'cosmological parameters', 'factor accounts', 'factor', 'such', 'informed', 'determination', 'denoted', 'corrected', 'calibration', 'assumption', 'assumed', 'applying', 'additionally']
# ['“ hydrostatic mass bias ” factor', 'x_ray cluster masses errors', 'true masses', 'multiplying', 'corrected']
# In the Planck analysis, systematic errors in X-ray cluster masses are corrected by applying a "hydrostatic mass bias" factor, denoted as (1 − b). This factor accounts for the expected bias in X-ray derived masses, which are assumed to be low due to the assumption of hydrostatic equilibrium. The calibration of this bias factor is informed by weak gravitational lensing estimates, with various constraints provided, such as (1−b) = 0.69±0.07, (1 − b) = 0.78 ± 0.08, and 1/(1 − b) = 0.99 ± 0.19. Additionally, the determination of cosmological parameters from Planck cluster counts relies on the mass bias parameter, with a derived constraint of (1 − b) = 0.62 ± 0.03.
# The X-ray cluster masses errors are corrected by multiplying the true masses by a “hydrostatic mass bias” factor.
# [0.92422027 0.94115813 0.82330894 0.85215566 1.        ] 0.9081686008055897
#
# ['full joint des likelihood reduces', 'σ8 – ωm plane', 'baseline planck likelihood', 'des galaxy correlation', 'des data alone', 'confidence contours overlapping', '0_832 ± 0_013', '0_811 ± 0_011', '0_8062 ± 0_00574', '0_793 ± 0_024', '0_315 ± 0_0073', '0_3040 ± 0_0060', '0_023 − 0_0312', 'planck cmb data', '0_06 ev ):', 'planck 2018 results', 'planck results', 'combining des', '∑ mν', 'two datasets', 'parameter constraints', 'moderate tension', 'lensing ):', 'error bars', 'base_λcdm model', 'approximately 2', 'σ8', 'ωm', 'ωm', 'ωm', 'lensing', 'tt', 'te', 's8', 's8', 's8', 'resulting', 'pte', 'lowe', 'indicating', 'follows', 'ee', 'between', 'along', '95', '8', '1', '0_256']
# ['0_811 ± 0_011', '0_8062 ± 0_0057', '0_3040 ± 0_0060', 'ω_m', 'σ_8', 's_8']
# The parameter constraints from the DES galaxy correlation and lensing, along with the Planck 2018 results, are as follows:1. From the DES data alone (with a base-ΛCDM model and ∑mν = 0.06 eV): - S8 = 0.793 ± 0.024 - Ωm = 0.256+0.023−0.0312. From the Planck results (TT,TE,EE+lowE+lensing): - S8 = 0.832 ± 0.013 - Ωm = 0.315 ± 0.0073. When combining DES with the baseline Planck likelihood: - S8 = 0.811 ± 0.011 - Ωm = 0.3040 ± 0.0060 - σ8 = 0.8062 ± 0.00574. The full joint DES likelihood reduces the error bars in the σ8–Ωm plane, resulting in only 95% confidence contours overlapping with Planck CMB data, indicating a moderate tension (approximately 2% PTE) between the two datasets. [8]
# S_8 = 0.811 \pm 0.011,
# \Omega_m = 0.3040 \pm 0.0060,
# \sigma_8 = 0.8062 \pm 0.0057,
# [1.         0.99352867 1.         1.         1.         1.        ] 0.9989214445695148
#
# ['primary non_cmb astrophysical data set', 'consistently shown excellent agreement', 'simple_different different bao measurements', 'making bao measurements insensitive', 'best_fit base_λcdm cosmology inferred', 'other non_cmb data', 'robust geometrical test', 'much larger than', 'approximately 147 mpc', 'acoustic scale measured', 'bao results', 'virialized structures', 'significant importance', 'reliability compared', 'pm 0_0060', 'pm 0_0057', 'nonlinear physics', 'galaxy surveys', 'cosmological studies', 'characteristic enhances', 'planck papers', 'cosmology', 'scale', 'planck', 'utilized', 'significance', 'sigma_8', 'serve', 'reinforcing', 'providing', 'furthermore', 'baos', '0_8062', '0_3040']
# ['much larger than', 'virialzed strucutres', 'robust test', 'non_linear physics', 'acoustic scale', 'scale makes', 'makes', 'sensitive', 'cosmology', 'bao']
# 0.3040 \pm 0.0060, \sigma_8 = 0.8062 \pm 0.0057, Simple_Different Different BAO measurements are utilized with significant importance in Planck papers because they serve as the primary non-CMB astrophysical data set, providing a robust geometrical test of cosmology. The acoustic scale measured by BAOs, approximately 147 Mpc, is much larger than the scale of virialized structures, making BAO measurements insensitive to nonlinear physics. This characteristic enhances their reliability compared to other non-CMB data. Furthermore, BAO results from galaxy surveys have consistently shown excellent agreement with the best-fit base-ΛCDM cosmology inferred from Planck, reinforcing their significance in cosmological studies.
# The acoustic scale of BAO is much larger than that of virialzed strucutres. This scale makes it a robust test of cosmology and makes it sensitive to non-linear physics
# [1.         0.93785721 0.92165423 0.98246446 0.96674792 0.92017522
#  0.7        0.81235572 1.         1.        ] 0.9241254759490461
#
# ['comoving angular diameter distance', 'sharply_defined acoustic angular scale', 'comoving sound horizon', 'cmb power spectrum', 'acoustic oscillations', 'relationship between', 'r ∗)', 'primarily driven', 'oscillations correspond', 'dm ).', 'distances quantifies', 'photon_baryon perturbations', 'cmb', 'perturbations', 'sky', 'recombination', 'recombination', 'occur', 'influence', 'far', 'determined']
# ['purely adiabatic perturbations driving', 'strong evidence', 'acoustic oscillations']
# The acoustic oscillations of the CMB power spectrum are primarily driven by the photon-baryon perturbations that occur at recombination. These oscillations correspond to a sharply-defined acoustic angular scale on the sky, which is determined by the comoving sound horizon at recombination (r∗) and the comoving angular diameter distance (DM). The relationship between these distances quantifies how far the perturbations can influence the CMB.
# There is very strong evidence for purely adiabatic perturbations driving the acoustic oscillations.
# [0.8443689  0.81560239 1.        ] 0.8866570958861336
#
# ['no relevant sources', 'no information given']
# ['ly αbaos result', 'bao result', 'overall 2_3σtension', 'joint planck']
# No information given. No relevant sources.
# The joint Planck+BAO result has an overall 2.3\sigma tension with the Ly \alpha BAOs result.
# [0.72812725 0.76856232 0.76104617 0.76616397] 0.7559749268606727
#
# ['planck 2018 tt', 'confidence level ).', '7_68 ± 0_79', 'mid_point redshift', 'lowe analysis', 'zre', 'te', 'reionisation', 'ee', 'according', '68']
# ['7_68 ± 0_79']
# The mid-point redshift of reionisation, according to the Planck 2018 TT, TE, EE+ lowE analysis, is zre = 7.68 ± 0.79 (68% confidence level).
# 7.68 \pm 0.79
# [1] 1.0
#
# ['high_l likelihood **: significant changes also arose', '** new polarization low_l likelihood **:', 'new hfi low_l polarization likelihood', 'cold dark matter density parameter', 'cosmic microwave background polarization', 'ase − 2τ degeneracy', '\x03 bbcdm parameters between', 'beam_leakage correction affected ωc', 'te high_l likelihood', '** polarization corrections', '2015 lfi likelihood', 'adjustment also led', 'two main effects', 'gravitational lensing smoothing', 'τ ), resulting', 'polarization spectra', 'baryon density', 'beam_leakage corrections', '− 0_7σ', 'ωc ).', 'planck 2015', 'adjustment decreased', 'corrections resulted', 'corrections applied', 'θ ∗)', 'tighter constraint', 'spectral index', 'sound horizon', 'primarily due', 'primarily due', 'previous shift', 'optical depth', 'maintain power', 'largest contributor', 'improved data', 'high multipoles', 'change led', 'angular scale', '2018 releases', '0_7σ ).', 'approximately 0_5σ', 'approximately 0_5σ', 'adjustments reflect', 'ns due', 'around 1σ', 'parameters', 'τ', '0_5σ', 'change', 'adjustments', 'ns', 'ns', '1σ', '1σ', 'ωb', 'ωb', 'θmc', 'shifts', 'shifted', 'replacing', 'overall', 'necessitating', 'methodologies', 'ln', 'introduction', 'increasing', 'increase', 'increase', 'increase', 'impact', 'differences', 'decreasing', 'decrease', 'consequently', 'compensating', 'analysis', 'along', 'additionally', '2', '1010as', '1']
# ['new polarization low_l likelihood', 'polarization corrections', 'high_l likelihood']
# The differences in the bbCDM parameters between the Planck 2015 and 2018 releases are primarily due to two main effects:1. **New Polarization Low-` Likelihood**: The introduction of the new HFI low-` polarization likelihood, replacing the 2015 LFI likelihood, is the largest contributor to the shifts in parameters. This change led to a tighter constraint on the optical depth (τ), resulting in a decrease of ln(1010As) by 1σ through the Ase−2τ degeneracy. Consequently, this adjustment decreased the gravitational lensing smoothing at high multipoles, necessitating an increase of about 1σ in the cold dark matter density parameter (ωc). To maintain power, the spectral index (ns) shifted down by about 0.5σ, along with adjustments in the angular scale of the sound horizon (θ∗) and baryon density (ωb) by approximately 0.5σ.2. **Polarization Corrections in the High-` Likelihood**: Significant changes also arose from corrections applied to the polarization spectra. These corrections resulted in an increase in ωb by around 1σ, primarily due to beam-leakage corrections in the TE high-` likelihood. This adjustment also led to an increase of approximately 0.5σ in ns, compensating for the previous shift in ns due to the change in τ. Additionally, the beam-leakage correction affected ωc (decreasing it by −0.7σ) and θMC (increasing it by +0.7σ). Overall, these adjustments reflect the impact of improved data and methodologies in the analysis of cosmic microwave background polarization.
# A new polarization low-l likelihood and polarization corrections in the high-l likelihood.
# [0.94698845 0.94037101 0.92147145] 0.9362769726689463
#
# ['tt likelihood utilizes four half_mission cross_spectra', '30 ≤ l ≤ 2508', '30 ≤ l ≤ 1996', '217_ghz hfi frequency maps', '505 – 1996 ).', 'half_mission cross_spectra measured', '30 – 2508', '30 – 2508', '30 – 1996', '30 – 1996', '505 – 1996', '30 – 999', '30 – 999', '30 – 1197', '505 – 999', 'planck 2018 analysis', '217 × 217', '217 × 217', '143 × 217', '143 × 217', '143 × 143', '143 × 143', '100 × 217', '100 × 143', '100 × 100', '100 × 100', 'following multipole cuts', 'additional cross_spectra', 'multipole cuts', 'signal_to_noise ratio', 'multipoles used', 'high_multipole likelihoods', 'tt', 'ee likelihoods', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'ee', 'te', 'te', 'specifically', 'range', 'included', 'enhance', 'constructed', '143_', '100_']
# ['217_ghz hfi frequency maps', '143_', '100_']
# The high-multipole likelihoods in the Planck 2018 analysis are constructed from half-mission cross-spectra measured from the 100-, 143-, and 217-GHz HFI frequency maps. The multipoles used are in the range of 30 ≤ ` ≤ 2508 for TT and 30 ≤ ` ≤ 1996 for TE and EE. Specifically, the TT likelihood utilizes four half-mission cross-spectra with the following multipole cuts: - 100 × 100 (` = 30–1197)- 143 × 143 (` = 30–1996)- 143 × 217 (` = 30–2508)- 217 × 217 (` = 30–2508)For TE and EE likelihoods, additional cross-spectra are included to enhance the signal-to-noise ratio, with these multipole cuts:- 100 × 100 (` = 30–999)- 100 × 143 (` = 30–999)- 100 × 217 (` = 505–999)- 143 × 143 (` = 30–1996)- 143 × 217 (` = 505–1996)- 217 × 217 (` = 505–1996).
# The 100-, 143-, and 217-GHz HFI frequency maps.
# [1 1 1] 1.0
#
# ['planck 2018 lowe analysis', 'pm 0_0086 \\)', 'optical depth \\(', 'tau \\)', '\\( 0_0506', 'confidence level', 'cl ).', 'according', '68']
# ['0_0506 ± 0_0086']
# According to the Planck 2018 lowE analysis, the optical depth \( \tau \) is \( 0.0506 \pm 0.0086 \) with a 68% confidence level (CL).
# 0.0506 \pm 0.0086
# [0.89480523] 0.8948052293200481
#
# ['high angular resolution', 'connected 4_point function', 'planck 2018 paper', 'low_noise observations', 'e_mode polarization', 'cmb photons', 'cmb lensing', 'b_mode polarization', 'acoustic peaks', 'dominant effects', 'planck', 'effects', 'such', 'smoothing', 'measured', 'include', 'highlighted', 'generation', 'conversion', '3', '2', '1']
# ['connected 4_point function', 'e_mode polarization', 'b_mode polarization', 'acoustic peaks', 'smoothing', 'generation', 'conversion']
# The dominant effects of the CMB lensing on the CMB photons, as highlighted in the Planck 2018 paper, include: 1) a smoothing of the acoustic peaks, 2) conversion of E-mode polarization to B-mode polarization, and 3) generation of a connected 4-point function. These effects can be measured in high angular resolution, low-noise observations, such as those from Planck.
# Smoothing of the acoustic peaks, conversion of E-mode polarization to B-mode polarization, and generation of a connected 4-point function
# [1 1 1 1 1 1 1] 1.0
#
# ['significant (>∼ 2σ', 'henning et al', 'ee combined analysis', 'notable discrepancy between', 'planck λcdm cosmology', 'base_λcdm model tend', 'base_λcdm model', 'tensions between', 'planck solution', 'two datasets', 'strongly disfavors', 'sptpol likelihood', 'sptpol data', 'spt determinations', 'higher multipoles', 'drift away', 'planck 2018', 'cosmological parameters', 'parameters', '2018', 'yes', 'tension', 'te', 'suggesting', 'particularly', 'noted', 'indicating', 'extended', 'evidence', 'additionally']
# ['statistically significant inconsistency between', 'spt cosmological parameters', 'no evidence', 'planck']
# Yes, there is evidence of tensions between the Planck 2018 and the SPT determinations of cosmological parameters. Henning et al. (2018) noted a significant (>∼ 2σ) tension with the base-ΛCDM model, indicating that the parameters of the base-ΛCDM model tend to drift away from the Planck solution as the SPTpol likelihood is extended to higher multipoles. Additionally, the SPTpol data, particularly the TE+EE combined analysis, strongly disfavors the Planck ΛCDM cosmology, suggesting a notable discrepancy between the two datasets.
# No evidence for any statistically significant inconsistency between the Planck and the SPT cosmological parameters.
# [0.89945528 0.91398269 0.90864254 1.        ] 0.930520127877692
#
# ['internal tensions observed between', 'high multipole results indicate', 'high multipole likelihood predicts', 'cmb lensing amplitude parameter', 'high multipole likelihoods', 'parameter ωmh2 shows', 'notable difference between', 'cosmological parameters between', 'planck 2018 paper', 'moderate statistical fluctuations', 'higher matter density', '0_649 ± 0_018', 'low multipole range', 'lensing amplitude', 'multipole ranges', 'fluctuation amplitude', 'two ranges', 'spectral index', 'small scales', 'particularly related', 'lower values', 'low_l dip', 'large scales', 'hubble constant', '2_8σ level', 'low', 'σ8ω0_25m', 'thought', 'specifically', 'significant', 'ns', 'h0', 'differing', 'differences', 'correlation', 'consistent', 'compared', 'along', 'additionally']
# ['high multipole likelihoods', '2 differs between', 'ω_mh', 'low', 'approximately', '2σlevel']
# In the Planck 2018 paper, the differences in cosmological parameters between the low and high multipole likelihoods are significant. The high multipole results indicate a higher matter density and fluctuation amplitude, along with lower values for the spectral index (ns) and the Hubble constant (H0) compared to the low multipole range. Specifically, the high multipole likelihood predicts a CMB lensing amplitude parameter of σ8Ω0.25m = 0.649 ± 0.018. Additionally, the parameter Ωmh2 shows a notable difference between the two ranges, differing at the 2.8σ level. The internal tensions observed between these multipole ranges are thought to be consistent with moderate statistical fluctuations, particularly related to the low-` dip at large scales and its correlation with lensing amplitude on small scales.
# \Omega_mh^2 differs between the low and high multipole likelihoods at approximately the 2\sigma level
# [1.         0.88018155 1.         1.         0.88567891 0.7       ] 0.9109767419402576
#
# ['2 – 3 sigma level', '2 sigma significance level', '4_4 sigma level', 'riess et al', 'planck 2018 paper', 'tensions between', 'other tensions', 'other datasets', 'more than', 'more than', 'latest measurement', 'direct measurements', '2019 ).', 'not significant', 'significant', 'yes', 'specifically', 'results', 'however', 'h0', 'discrepancy', 'aside', 'according']
# ['planck results', 'direct measurements', '2 σlevel', 'inconsistent', 'h_0']
# Yes, there are tensions between the results in the Planck 2018 paper and other datasets at more than the 2 sigma significance level. Specifically, the discrepancy with direct measurements of H0 is significant at about the 4.4 sigma level, according to the latest measurement from Riess et al. (2019). However, aside from this, other tensions are not significant at more than the 2–3 sigma level.
# Only the direct measurements of H_0 are inconsistent with the Planck results at the 2 \sigma level.
# [0.89254916 1.         0.88885488 0.85898772 1.        ] 0.9280783537500108
#
# ['127 using second order lagrangian perturbation theory', '0_0 \\, ev \\), \\( w', '\\(\\ omega_m \\), \\(\\ sigma_8 \\),', '0_9624 \\), \\( m_ \x1a', '0_6711 \\), \\( n_s', '0_049 \\), \\( h', '\\(\\ omega_m \\) ranging', 'initial gaussian density field', 'parameters \\(\\ omega_m \\)', '\\(\\ sigma_8 \\)', '\\(\\ sigma_8 \\)', 'standard rescaling codes', 'mitigate prior effects', '2lpt ). 2', '0 \\). 5', 'initial random seed', 'initial power spectra', 'varied across simulations', '1 \\),', '\\(\\ omega_k', '\\(\\ omega_b', 'initial conditions', 'initial conditions', 'fixed across', 'cosmological parameters', 'total matter', 'several assumptions', 'redshift z', 'neural networks', 'n_body simulations', 'hydrodynamic simulations', 'growth rate', 'growth factor', 'dark matter', 'considered scale_independent', 'camels simulations', 'parameters', 'simulations', '1', 'use', 'same', 'output', 'made', 'generation', 'generated', 'gas', 'equal', 'determines', 'change', 'assumed', 'allows', '6', '4', '3', '1_0', '0_6', '0_5', '0_1']
# ['initial power spectra', 'total matter', 'hydrodynamic simulations', 'dark matter', 'same', 'gas', 'equal']
# In the generation of the initial conditions in the CAMELS simulations, several assumptions are made:1. The initial conditions are generated at redshift z = 127 using second order Lagrangian perturbation theory (2LPT).2. It is assumed that the initial power spectra of dark matter and gas in the hydrodynamic simulations are the same and equal to that of total matter.3. The growth factor and growth rate are considered scale-independent, which allows for the use of standard rescaling codes.4. Cosmological parameters are fixed across all simulations: \(\Omega_b = 0.049\), \(h = 0.6711\), \(n_s = 0.9624\), \(M_ = 0.0 \, eV\), \(w = -1\), and \(\Omega_K = 0\).5. The parameters \(\Omega_m\) and \(\sigma_8\) are varied across simulations, with \(\Omega_m\) ranging from 0.1 to 0.5 and \(\sigma_8\) from 0.6 to 1.0, to mitigate prior effects on the output of neural networks.6. In the N-body simulations, the only parameters that change are \(\Omega_m\), \(\sigma_8\), and the initial random seed that determines the initial Gaussian density field.
# That the initial power spectra of dark matter and gas in the hydrodynamic simulations are the same, and equal to that of total matter.
# [1 1 1 1 1 1 1] 1.0
#
# ['approximately 2 kpc comoving', 'illustristng model used', 'spatial resolution', 'camels']
# ['2 kpc comoving']
# The spatial resolution for the IllustrisTNG model used in CAMELS is approximately 2 kpc comoving.
# 2 kpc comoving
# [0.96819375] 0.9681937470765078
#
# ['main methodological difference between', 'enables different parameter variations', 'two galaxy formation models', 'wind velocity parametrizations used', 'galaxy circular velocity', 'galactic wind efficiency', 'wind velocity normalization', 'wind kinetic energy', 'wind velocity', 'wind velocity', 'specific formula', 'not impose', 'greater flexibility', 'fire model', 'control over', 'available supernova', 'energy', 'sne', 'simba', 'scales', 'results', 'necessary', 'limits', 'incorporating', 'contrast', 'constraint', 'camels', 'camels', 'based', 'attenuation', 'allowing', '18']
# ['calculated using dark matter velocity dispersion', 'galaxy circular velocity', 'calculated using', 'hubble constant', 'v_w', 'v_w', 'simba', 'illustristng']
# The main methodological difference between the wind velocity parametrizations used by the two galaxy formation models in CAMELS is that SIMBA's wind velocity is based on the FIRE model and scales with galaxy circular velocity, incorporating a specific formula that limits the wind kinetic energy to the available supernova (SNe) energy. This results in an attenuation of wind velocity when necessary. In contrast, CAMELS does not impose this constraint, allowing for greater flexibility and control over the galactic wind efficiency, which enables different parameter variations in the wind velocity normalization. [18]
# In IllustrisTNG, v_w is calculated using dark matter velocity dispersion and the Hubble constant, while in SIMBA, v_w is calculated using the galaxy circular velocity.
# [0.82080393 1.         0.83166669 0.80057667 0.7        0.7
#  1.         0.7       ] 0.8191309107455162
#
# ['six parameters (\\(\\ omega_m \\), \\(\\ sigma_8 \\), asn1', '\\(\\ omega_m \\), \\(\\ sigma_8 \\),', 'different ways across several sets', 'varied include six key cosmological', 'random seed constant across', '** ex set **:', '** cv set **:', '** 1p set **:', 'set contains 4 simulations', 'initial random seed', '** latin hypercube', 'four astrophysical parameters', 'astrophysical parameters vary', 'includes 27 simulations', 'set **:', 'cosmological parameters', 'astrophysical parameters', 'astrophysical parameters', 'varied simultaneously', 'varied one', 'held constant', 'asn1', 'camels simulations', '61 simulations', 'same values', 'agn feedback', 'set', 'parameters', 'cosmological', '4', 'simulations', 'simulations', 'variations', 'time', 'strength', 'stellar', 'share', 'parameter', 'lh', 'keeping', 'implemented', 'differing', 'control', 'consists', 'asn2', 'asn2', 'aagn2', 'aagn2', 'aagn1', 'aagn1', '3', '2', '1']
# ['parameters andd initial conditions differently', 'same initial random seed', 'fixed initial random seeds', '4 different simulation sets', 'different initial random seeds', 'different inital seeds', 'represents extreme feedback', 'one paramter', 'parameters', 'parameters', 'vary', 'varies', 'varied', 'time', 'run', 'lh', 'fixes', 'ex', 'cv', 'camels', '1p']
# In the CAMELS simulations, the parameters that are varied include six key cosmological and astrophysical parameters: \(\Omega_m\), \(\sigma_8\), and four astrophysical parameters (ASN1, ASN2, AAGN1, and AAGN2) that control the strength of stellar and AGN feedback. The variations are implemented in different ways across several sets of simulations:1. **Latin Hypercube (LH) Set**: In this set, all six parameters (\(\Omega_m\), \(\sigma_8\), ASN1, ASN2, AAGN1, AAGN2) are varied simultaneously.2. **1P Set**: This consists of 61 simulations where each parameter is varied one at a time, while keeping the random seed constant across all simulations.3. **CV Set**: This includes 27 simulations that share the same values for the cosmological and astrophysical parameters, differing only in their initial random seed.4. **EX Set**: This set contains 4 simulations where the cosmological parameters are held constant, but the astrophysical parameters vary.
# 4 different simulation sets are run in CAMELS, which vary the parameters andd initial conditions differently. (LH) varies all parameters and has different inital seeds, (1P) has the same initial random seed, where only one paramter is varied at a time, (CV) fixes the parameters and has different initial random seeds and (EX) represents extreme feedback with fixed initial random seeds.
# [0.85210609 0.93778329 0.93861984 0.95018153 0.94554227 0.89297382
#  0.80173155 0.87999995 1.         1.         0.87478813 0.7
#  0.95005916 1.         0.83472122 1.         0.7        0.82455733
#  1.         1.         1.        ] 0.9087173412024401
#
# ['0_5 h − 1 kpc', 'softening length', 'n_body simulations', 'set', 'camels']
# ['0_5 h ^- 1kpc']
# The softening length for the N-body simulations in CAMELS is set to 0.5 h−1 kpc.
# 0.5 h^{-1}kpc
# [0.94828259] 0.9482825916532495
#
# ['cosmic variance versus changes', 'matter power spectrum', 'cosmic variance dominates', 'difference between cosmological', 'astrophysical parameter variations', 'cosmic variance', 'astrophysical parameters', 'astrophysical parameters', 'small scales', 'random variations', 'measured quantities', 'large scales', 'initial conditions', 'greater impact', 'findings indicate', 'distinction helps', 'camels quantifies', 'changes', 'variations', 'cosmological', 'cosmological', 'variation', 'variation', 'variation', 'variation', 'understanding', 'specifically', 'sources', 'range', 'range', 'fraction', 'due', 'cosmology', 'contributions', 'astrophysics', 'assesses', 'analyzing']
# ['illustristng lh', 'cv sets', '84 percentiles', 'median', 'compute', '16']
# CAMELS quantifies the difference between cosmological/astrophysical parameter variations and random variations in the initial conditions by analyzing the contributions of cosmic variance and changes in cosmological and astrophysical parameters to the range of variation in measured quantities. Specifically, it assesses what fraction of the variation is due to cosmic variance versus changes in cosmology and astrophysics. The findings indicate that on large scales, cosmic variance dominates the range of variation, while on small scales, variations in cosmological and astrophysical parameters have a greater impact. This distinction helps in understanding the sources of variation in the matter power spectrum.
# They compute the median and 16-84 percentiles of the IllustrisTNG LH and CV sets.
# [0.77526912 0.76974702 0.78420412 0.85964681 0.81658764 0.80596399] 0.8019031148113832
#
# ['stellar masses less than 5 × 10', '** halo temperatures **: halo temperatures', '** galaxy sizes **: simba galaxies', '** black hole mass variation **:', '10 h − 1m ⊙,', '** baryon fractions **:', '** variation range **:', 'black hole mass', 'low stellar masses', 'generally smaller than', 'consistently lower than', 'systematic differences between', 'generally larger than', 'simba simulation set', 'higher masses', 'baryon fractions', 'fixed mass', 'simba suites', 'simba compared', 'systematically higher', 'camels include', '5', 'galaxies', 'variation', 'variation', 'simba', 'range', 'range', 'larger', 'ranges', 'illustristng', 'illustristng', 'illustristng', 'illustristng', 'illustristng', 'illustristng', 'except', 'comparable', '4', '3', '2', '1', '1']
# ['gas power spectra', 'systematic differences', 'baryon fractions']
# The systematic differences between the IllustrisTNG and SIMBA suites in CAMELS include:1. **Halo Temperatures**: Halo temperatures at fixed mass are systematically higher in SIMBA compared to IllustrisTNG.2. **Galaxy Sizes**: SIMBA galaxies are generally larger than those in IllustrisTNG, except for galaxies with low stellar masses.3. **Variation Range**: The range of variation in the SIMBA simulation set is generally smaller than that in IllustrisTNG.4. **Black Hole Mass Variation**: For stellar masses less than 5 × 10^10 h−1M⊙, the range of variation in black hole mass is larger in IllustrisTNG, while at higher masses, the ranges are comparable.5. **Baryon Fractions**: The baryon fractions in SIMBA are consistently lower than those in IllustrisTNG. 1.
# The systematic differences are in the gas power spectra and the baryon fractions
# [0.78149223 0.97446704 1.        ] 0.9186530875043935
#
# ['parameter space differently due', 'distinct subgrid models used', '** astrophysics parameters **:', '** baryon fractions **:', 'large intrinsic differences between', '** model robustness **:', 'galaxy models **:', '** intrinsic differences', 'similar qualitative dependence', 'several key factors', 'not perform well', 'matter density parameter', 'consistently lower than', 'systematic differences between', 'galaxy properties lead', 'baryon fractions', 'models trained', 'astrophysical parameters', 'baryonic matter', 'model trained', 'illustristng properties', 'ωm ),', 'vice versa', 'two suites', 'simulation suite', 'one suite', 'galaxies produced', 'fundamental difference', 'different meanings', 'simba suites', 'simba simulations', 'simba galaxies', 'illustristng simulations', 'illustristng simulations', 'robustness', 'differences', 'differences', 'model', 'simba', 'illustristng', 'treated', 'tested', 'outputs', 'other', 'occupy', 'lack', 'indicating', 'exhibit', 'contributes', 'camels', 'behaviors', 'attributed', 'applied', 'although', '4', '3', '2', '1', '1']
# ['different subgrid feedback implementations', 'different feedback implementations', 'effective feedback strengths', 'gas power spectra', 'systematic differences', 'parameter variations', 'baryon fractions', 'respectively', 'reasons']
# The systematic differences between the IllustrisTNG and SIMBA suites in CAMELS can be attributed to several key factors:1. **Intrinsic Differences in Galaxy Models**: There are large intrinsic differences between the galaxies produced by the SIMBA and IllustrisTNG simulations. Although both exhibit a similar qualitative dependence on the matter density parameter (Ωm), they occupy the parameter space differently due to the distinct subgrid models used in each simulation suite.2. **Baryon Fractions**: The baryon fractions in the SIMBA simulations are consistently lower than those in the IllustrisTNG simulations, indicating a fundamental difference in how baryonic matter is treated in each model.3. **Astrophysics Parameters**: The astrophysical parameters in the two suites have very different meanings, which contributes to the differences in their outputs and behaviors.4. **Model Robustness**: The differences in galaxy properties lead to a lack of robustness in models trained on one suite when tested on the other. A model trained on IllustrisTNG properties does not perform well when applied to SIMBA galaxies, and vice versa. 1.
# The reasons for the systematic differences in the gas power spectra and the baryon fractions are the different subgrid feedback implementations and effective feedback strengths and the different feedback implementations and parameter variations, respectively.
# [0.88292895 0.77663774 0.81373371 0.80811886 0.97446704 0.85183797
#  1.         0.82916394 0.7       ] 0.8485431345195497
#
# ['generates 2d gas temperature maps using generative adversarial networks', 'learning models :** supervised learning models :** 1', 'following machine learning tasks utilize different types', '** unsupervised learning models :** 1', '2d gas maps using convolutional auto_encoders', '2d gas maps using convolutional auto_encoders', 'finds lower dimensionality representation', 'constrains parameter values', 'predicts average sfrd', 'dimensionality reduction', 'parameter regression', 'symbolic regression', 'mean sfrd', 'identifies anomalies', 'data generation', 'camels project', 'anomaly detection', 'analytic expressions', 'sfrd', 'parameters', 'measurements', 'emulator', 'approximates', '3', '3', '2', '2']
# ['unsupervised learning models', 'supervised learning models', 'symbolic regression', 'dimensionality reduction', 'data generation', 'anomaly detection', 'parameter', 'handled', 'handled', 'emulator']
# In the CAMELS project, the following machine learning tasks utilize different types of learning models:**Supervised Learning Models:**1. Emulator - Predicts average SFRD from parameters.2. Parameter Regression - Constrains parameter values from measurements of the SFRD.3. Symbolic Regression - Approximates the mean SFRD with analytic expressions.**Unsupervised Learning Models:**1. Data Generation - Generates 2D gas temperature maps using generative adversarial networks.2. Dimensionality Reduction - Finds lower dimensionality representation of 2D gas maps using convolutional auto-encoders.3. Anomaly Detection - Identifies anomalies in 2D gas maps using convolutional auto-encoders.
# The emulator, parameter and symbolic regression are all handled by supervised learning models and the data generation, dimensionality reduction and anomaly detection are all handled by unsupervised learning models.
# [0.91341102 0.9178004  1.         1.         1.         1.
#  0.94690952 0.80404011 0.80404011 1.        ] 0.9386201170049642
#
# ['star formation rate density', 'precision across different redshifts', 'models maintain similar accuracy', 'slight improvement noted', 'predict cosmological quantities', 'higher redshifts', 'using cosmological', 'cosmological quantity', 'sfrd ),', 'reasonable level', 'neural network', 'network demonstrates', 'competent ability', 'astrophysical parameters', '0_12 dex', 'accuracy', 'predict', 'δ', 'therefore', 'specifically', 'redshift', 'predictions', 'indicates', 'function', 'evolution', 'error', 'camels', 'additionally', '1']
# ['neural network achieves', 'approximate error rate', '30']
# The neural network of CAMELS can predict the evolution of a cosmological quantity, specifically the Star Formation Rate Density (SFRD), with an error of δ = 0.12 dex when using cosmological and astrophysical parameters. This indicates a reasonable level of accuracy in its predictions. Additionally, the models maintain similar accuracy and precision across different redshifts, with a slight improvement noted at higher redshifts. Therefore, the network demonstrates a competent ability to predict cosmological quantities as a function of redshift. 1.
# The neural network achieves an approximate error rate of 30% for training data that contains 20% "error"/scatter due to cosmic variance.
# [0.90652121 0.84180769 0.81528367] 0.8545375233740277
#
# ['no relevant sources', 'no information']
# ['penalises more complex operations', 'integer number associated', 'operator', 'functions', 'complexity']
# No information. No relevant sources.
# Complexity is an integer number associated to each operator, which penalises more complex operations in the functions
# [0.7706919  0.78409594 0.77866474 0.7        0.78716714] 0.7641239458071611
#
# ['neural networks perform better than', 'equations achieved approximately 45', 'symbolic regression equations', 'neural network achieved', 'neural networks', 'neural network', 'provided information', 'camels results', '0_106 error', 'cosmological quantities', 'accuracy compared', 'better', 'quantities', 'accuracy', 'δ', 'therefore', 'redshift', 'modeling', 'modeling', 'evolution', 'based', '30', '3', '2', '1']
# ['symbolic regression equation', 'lower δerror than', 'generally more robust', 'physics behind', 'neural network', 'cosmological processes', 'understanding', 'help', 'extrapolations', 'equations']
# Based on the provided information, the neural networks perform better than the symbolic regression equations in modeling the evolution of cosmological quantities with redshift in the CAMELS results. The neural network achieved a δ = 0.106 error, while the equations achieved approximately 45% accuracy compared to the neural network's 30% accuracy. Therefore, the neural networks are better at modeling these quantities. 1. 2. 3.
# While the neural network has a lower \delta error than the symbolic regression equation, the equations are generally more robust in extrapolations and can help in understanding the physics behind the cosmological processes.
# [0.98876588 0.79910503 0.85665264 0.80660487 1.         0.89918931
#  0.81366405 0.83443878 0.7        1.        ] 0.8698420563309728
#
# ['unsupervised generative models involves', 'discriminator becomes more adept', 'differentiate between real', 'produce better images', 'increasingly skilled discriminator', 'real images', 'fake images', 'create images', 'successfully deceive', 'same properties', 'feedback loop', 'dynamic creates', 'discriminator', 'discriminator', 'task', 'role', 'possess', 'output', 'mission', 'iteration', 'improve', 'generator', 'generator', 'generator', 'generator', 'compelled', 'challenges', 'camels', 'architecture']
# ['adverserial dynamic produces better data', 'two networks present', 'former generates data', 'original data', 'original data', 'generated data', 'same properties', 'latter tries', 'generative model', 'difference between', 'iteration', 'generator', 'distinguish', 'discriminator']
# In CAMELS, the architecture of the unsupervised generative models involves a generator and a discriminator. The generator's mission is to create images that possess the same properties as real images, while the discriminator's role is to differentiate between real and fake images. As the discriminator becomes more adept at its task, it challenges the generator to improve its output. This dynamic creates a feedback loop where the generator is compelled to produce better images in each iteration to successfully deceive the increasingly skilled discriminator.
# There are two networks present in the generative model: the generator and the discriminator. The former generates data that has the same properties as the original data and the latter tries to distinguish the difference between the original data and the generated data. This adverserial dynamic produces better data on each iteration.
# [0.83205124 0.77226514 0.85303222 0.85725531 0.85725531 0.83556274
#  1.         0.80820125 0.88264931 0.82631399 1.         1.
#  0.83984963 1.        ] 0.8831740094165009
#
# ['distributions over nearly four orders', '30 hmpc − 1', '1 hmpc − 1', 'strong correlation suggests', 'not significantly affected', 'level across scales', 'fake data generated', 'excellent agreement between', 'excellent agreement', 'fake images', 'real data', 'mode collapse', 'images produced', 'highly representative', 'almost indistinguishable', 'real ones', 'results agreeing', 'between', 'real', 'results', 'temperature', 'realistic', 'quantitatively', 'magnitude', 'looking', 'k', 'k', 'gans', 'gans', 'gan', 'effective', 'described', 'camels', 'approximately', 'also', 'additionally', '25', '15']
# ['fake images agree', 'results', 'real', 'approximately', '15']
# ...
# Custom alternatives to HMcode are used or restrictions to linear scales are made.
# [1.         0.87143688 0.86102067 0.7        0.86471105 1.        ] 0.8828614327645371
#
# ['cosmological parameter determination between', 'wmap λcdm best_fit model', 'act dr6 multi_frequency likelihood', 'ignoring correlations between', 'dr6 results agree', 'dr6 measurement', 'cmb_only likelihood', 'act dr4', 'ωbh2 shows', 'within 1σ', 'upward shift', 'two datasets', 'large_scale modes', '3σ compared', '2_8σ level', 'wmap', 'level', 'dr4', 'dr4', 'tension', 'specifically', 'indicated', 'however', 'difference', 'combined']
# ['no significant tension', 'agreement within 0_1σ']
# The level of tension in the cosmological parameter determination between the ACT DR6 multi-frequency likelihood and the CMB-only likelihood is indicated by a difference at the 2.8σ level when ignoring correlations between the two datasets. Specifically, the DR6 measurement of Ωbh2 shows an upward shift of 3σ compared to DR4. However, when ACT DR4 is combined with large-scale modes from WMAP, the DR6 results agree with the DR4 + WMAP ΛCDM best-fit model to within 1σ.
# No significant tension. Agreement within 0.1\sigma.
# [0.88820381 0.91520168] 0.9017027470683227
#
# ['\x7f 2 statistic', 'posteriori mflike likelihood', 'full p_act dataset', '\x03 bbcdm model', 'using', 'maximum', '2180_5']
# ['2180_5']
# The 2 statistic for the maximum a posteriori MFLike likelihood for the bbCDM model, using the full P-ACT dataset, is 2180.5.
# 2180.5
# [1] 1.0
#
# ['act dr6 mildly favors', '68 %, p_act_lb ).', '68 %, p_act', '0_0062 ± 0_0052', '0_0060 ± 0_0055', 'slight positive running', 'findings indicating dns', 'vanishing running', 'positive value', 'spectral index', 'spectral index', 'ln k', 'ln k', 'also confirming', 'dns', 'suggests', 'preference']
# ['no statisitically significant evidence', 'zero value', 'spectral index', 'positive value', 'negative value', 'midly favours', 'results disfavour', 'results', 'disfavour', 'running', 'favour']
# ACT DR6 mildly favors a slight positive running of the spectral index, with findings indicating dns/d ln k = 0.0060± 0.0055 (68%, P-ACT) and dns/d ln k = 0.0062± 0.0052 (68%, P-ACT-LB). This suggests a preference for a positive value, while also confirming a vanishing running of the spectral index.
# The results disfavour a negative value and midly favours a positive value for the running of the spectral index. There is no statisitically significant evidence in the results to favour or disfavour a zero value.
# [0.80416402 0.87914224 1.         1.         0.90510779 0.82695619
#  0.80282693 0.7        0.7        0.86641264 0.7       ] 0.8349645282198956
#
# ['act dr6 paper considers two possible non_decaying isocurvature modes', 'not analyzed directly due', 'cold dark matter density', 'less theoretically motivated', 'cmb power compared', 'not considered', 'neutrino density', 'baryon density', 'neutrino velocity', 'indistinguishable impact', 'indi ).', 'nvi', 'mode', 'mode', 'icdi', 'cdi', 'bdi']
# ['cold dark matter density', 'neutrino density', 'baryon density', 'considered indirectly', 'considered directly', 'ndi', 'cdi', 'bdi']
# The ACT DR6 paper considers two possible non-decaying isocurvature modes: cold dark matter density (ICDI) and neutrino density (INDI). The baryon density (BDI) mode is not analyzed directly due to its indistinguishable impact on the CMB power compared to CDI, and the neutrino velocity (NVI) mode is not considered because it is less theoretically motivated.
# Cold dark matter density (CDI) and neutrino density (NDI) are considered directly. Baryon density (BDI) is considered indirectly.
# [1.         1.         1.         0.87153332 0.86502168 1.
#  1.         1.        ] 0.9670693752240898
#
# ['3 ede model considered', 'act dr6 paper', 'act dataset', 'confidence level', 'value', 'n', 'h_0', 'h_0', '68', '67_5', '1_7', '0_9']
# ['67_7 ^+ 0_9_', '1_7']
# In the n=3 EDE model considered in the ACT DR6 paper, the value of H_0 from the ACT dataset at a 68% confidence level is H_0 = 67.5 +0.9 -1.7.
# 67.7^{+0.9}_{-1.7}
# [0.91983979 1.        ] 0.9599198969417215
#
# ['considered favoured over \x03 bb_cdm', 'less than 2σ', '3 ede model', 'significance level', 'p_act_lb dataset', 'n']
# ['1_7σ']
# The n=3 EDE model is considered favoured over bb-CDM for the P-ACT-LB dataset at a significance level of less than 2σ.
# 1.7\sigma
# [0.7] 0.7
#
# ['p_act_lbs showed no significant improvement', 'fit cmb data along', 'model could theoretically accommodate', 'non_standard electron mass', 'discrepancy between local', 'allowing electron mass', 'act dr6 paper', 'fit compared', 'spatial curvature', 'spatial curvature', 'significantly reduced', 'not support', 'not explain', 'late_time measurements', 'joint analysis', 'increased value', 'high value', 'global values', 'model', 'vary', 'therefore', 'such', 'scenario', 'recombination', 'recombination', 'quality', 'possibility', 'p_act_lb', 'obtaining', 'h_0', 'h_0', 'h_0', 'evidence', 'according']
# ['driving desi bao data', 'boss bao data', 'h_0 fits shifted', 'λ_cdm value', 'spatial curvature', 'global values', 'fully consistent', 'electron mass', 'discrepancy between', 'h_0', 'varying', 'therefore', 'replaced', 'no', 'local', 'explain']
# According to the ACT DR6 paper, allowing electron mass and spatial curvature to vary at recombination does not explain the discrepancy between local and global values of H_0. While such a model could theoretically accommodate an increased value of H_0 and fit CMB data along with late-time measurements, the joint analysis of P-ACT-LBS showed no significant improvement in the quality of fit compared to P-ACT-LB. Therefore, the evidence does not support a scenario with spatial curvature and a non-standard electron mass at recombination, and the possibility of obtaining a high value of H_0 from this model is significantly reduced.
# Once the driving DESI BAO data was replaced with the BOSS BAO data, the H_0 fits shifted to be fully consistent with the \lambda-CDM value. Therefore, no, varying the electron mass and spatial curvature doesn't explain the discrepancy between the local and global values of H_0
# [0.7474412  0.76099552 0.89818107 0.77634886 1.         1.
#  0.80875998 0.89387233 0.91589328 0.7        0.7        1.
#  0.7        0.81626676 0.8359071  0.86894614] 0.8389132660116154
#
# ['since additional relativistic species would increase damping', 'act dr6 paper constrain', 'primary cmb power spectra', 'excess high_ℓ damping', 'dr6 power spectra', 'cmb power spectra', 'significantly tighter than', 'relativistic species', 'previous limit', 'no evidence', 'effective number', 'preference', 'planck', 'nidr', 'nidr', 'nidr', 'leading', 'lack', 'improvement', 'finding', 'existence', 'disfavored', 'data', 'constraint', 'constraint', 'confidence', 'confidence', 'conclusion', 'authors', 'attributed', 'analyzing', '95', '95', '0_379', '0_339']
# ['cmb power spectra', 'characteristic phase shift', 'n_eff alters', 'damping tail', 'also induces', 'acoustic peaks']
# The authors of the ACT DR6 paper constrain the effective number of relativistic species (Nidr) from the CMB power spectra by analyzing the primary CMB power spectra and finding that Nidr < 0.339 at 95% confidence. This constraint is significantly tighter than the previous limit from Planck, which was Nidr < 0.379 at 95% confidence. The improvement in the constraint is attributed to the lack of preference for excess high-ℓ damping in the DR6 power spectra. Since additional relativistic species would increase damping, their existence is disfavored by the data, leading to the conclusion that there is no evidence.
# N_{eff} alters the damping tail of the CMB power spectra and also induces a characteristic phase shift in the acoustic peaks.
# [1.         0.76909499 0.83111644 0.85062506 0.7964685  0.78548611] 0.8387985181886218
#
# ['summ_ {\\ nu', 'less than 0_17', 'cl ), indicate', 'vary simultaneously', 'p_act_lb dataset', 'confidence level', 'delta n_', 'n_', 'using', 'eff', 'eff', 'constraints', 'constrained', 'allowed', '95']
# ['2_85 ± 0_25', 'n_eff', '_ν', '0_073ev']
# The constraints on both N_{eff} and \summ_{\nu} when allowed to vary simultaneously, using the P-ACT-LB dataset at the 95% confidence level (CL), indicate that \Delta N_{eff} is constrained to be less than 0.17.
# N_{eff}=2.85\pm0.25, \summ_{\nu}<0.073eV
# [0.82960983 0.7        0.7        0.7       ] 0.7324024572655197
#
# ['axion_like particle dynamics using several methods', 'avoid introducing spurious signals related', 'incorporates mixed dark matter', 'act dr6 paper model', 'comprehensive approach allows', 'axioncamb boltzmann solver', 'modified halo model', 'cmb power spectrum', 'cmb power spectrum', 'accurately model', 'modified version', 'small scales', 'small scales', 'previously applied', 'lss ).', 'large_scale structure', 'effectively analyze', 'axionemu emulator', 'axion physics', 'analyses regarding', 'power', 'cmb', 'utilize', 'implement', 'impacts', 'employ', 'effects', 'cosmopower', 'based', 'axions', 'axions', 'authors', 'additionally']
# ['modified halo model', 'mixed dark matter', 'use']
# The authors of the ACT DR6 paper model the CMB power spectrum on very small scales of axion-like particle dynamics using several methods. They utilize the axionCAMB Boltzmann solver, which has been previously applied in analyses regarding the impacts of axions on the CMB and large-scale structure (LSS). To accurately model the power on small scales and avoid introducing spurious signals related to axion physics, they implement a modified halo model that incorporates mixed dark matter. Additionally, they employ the axionEmu emulator, which is based on a modified version of CosmoPower. This comprehensive approach allows them to effectively analyze the effects of axions on the CMB power spectrum.
# They use a modified halo model, with mixed dark matter.
# [1.         0.92592393 0.86579084] 0.930571589006424
#
# ['multipole moments ℓ less than', 'power spectra would include', 'would reflect changes', 'low_ℓ acoustic peaks', 'dark matter annihilation', 'dark matter annihilation', 'cosmic microwave background', 'acoustic oscillations due', 'small angular scales', 'polarization power spectrum', 'larger scales', 'high_ℓ power', 'standard model', 'approximately equal', 'polarization signal', 'power', 'polarization', 'polarization', 'temperature', 'suggesting', 'sm', 'signs', 'shifts', 'reduction', 'particles', 'indicating', 'increase', 'fluctuations', 'enhancement', 'effects', 'damping', 'cmb', '400', '3', '2', '1']
# ['low_l acoustic peaks', 'l ≲ 400', 'polarisation power spectrum', 'high_l power', 'temperature', 'shifts', 'polarization', 'polarization', 'enhancement', 'damping']
# The signs of dark matter annihilation into Standard Model (SM) particles in the Cosmic Microwave Background (CMB) power spectra would include: 1. Damping of high-ℓ power in both temperature and polarization, indicating a reduction in the power of fluctuations at small angular scales.2. Enhancement of the polarization power spectrum at multipole moments ℓ less than or approximately equal to 400, suggesting an increase in the polarization signal at larger scales.3. Shifts of the low-ℓ acoustic peaks in polarization, which would reflect changes in the acoustic oscillations due to the effects of dark matter annihilation.
# Damping of high-l power in both temperature and polarization, enhancement of the polarisation power spectrum at l\lesssim400 and shifts of low-l acoustic peaks in polarization.
#
# [0.9576263  0.84803778 0.97767695 0.94240516 1.         1.
#  1.         1.         1.         1.        ] 0.972574618338707
#
# ['no relevant sources', 'no information']
# ['idr_idm model causes γ_0', 'n_idr approaches zero', 'become degenerate', 'bayesian constraints', 'nadm']
# No information. No relevant sources.
# Bayesian constraints on the IDR-IDM model causes \Gamma_{0, nadm} to become degenerate as N_{idr} approaches zero
# [0.72565081 0.7840928  0.75008129 0.7587054  0.7       ] 0.7437060609321969
#
# ['effectively breaks degeneracies between', 'central values remain consistent', 'growth index parameter γ', 'growth index increases', 'result primarily come', 'redshift space distortions', 'peculiar velocity surveys', 'more than 3σ', 'including fσ8 measurements', 'central values', 'γ derived', 'tension level', 'significant discrepancy', 'other parameters', 'not include', 'move away', 'general relativity', 'gr prediction', 'gr prediction', 'constraints deviate', 'γ', 'measurements', 'gr', 'constraints', 'specifically', 'rsd', 'results', 'indicating', 'data', 'contribute', 'calculation', 'analyses', 'although', '3_5σ', '0_55']
# ['fσ_8 dataset contains two low_z points', 'two points removes', 'low error bars', 'fσ_8 dataset', 'w_act datasets', 'tension between', 'lie below', 'cmb expectation', 'dataset', 'removing', 'p_act']
# Including fσ8 measurements in the calculation of the growth index increases the tension level with General Relativity (GR) because it effectively breaks degeneracies between the growth index parameter γ and other parameters. This results in constraints that move away from the GR prediction of γ = 0.55 at more than 3σ. Specifically, the central values of γ derived from these constraints deviate from the GR prediction at 3.5σ, indicating a significant discrepancy. The data that contribute to this result primarily come from Redshift Space Distortions (RSD) and peculiar velocity surveys, although the central values remain consistent with analyses that do not include these measurements.
# The f\sigma_8 dataset contains two low-z points with low error bars that lie below the CMB expectation for this dataset. Removing these two points removes the tension between the f\sigma_8 dataset and the P-ACT and W-ACT datasets.
# [0.82486449 0.78640629 0.81153751 0.90050458 0.77523142 0.88779126
#  0.8162845  0.76035842 0.7        0.83723268 0.7       ] 0.8000191948158815
#
# ['two measurements remain inconsistent', 'act dr6 paper', '\x03 bbcdm considered', 'act dr6 measurement', 'act dr6 measurement', 'latest sh0es measurement', '2024 sh0es measurement', 'ongoing tension between', 'h_0 falls within', 'tension between', 'cchp measurement', 'sh0es constraints', 'still below', 'p_act_lb limits', 'not help', 'not align', 'extended_model parameters', 'h_0', 'specifically', 'results', 'resolve', 'range', 'p_act', 'indicates', 'highlighting', 'extensions', 'degeneracies']
# ['still lower than', 'act dr6 paper', '2024 sh0es measurement', 'models studied', 'h_0 given', 'h_0', 'range', 'no']
# The extensions to bbCDM considered in the ACT DR6 paper do not help to resolve the tension between the ACT DR6 measurement of H_0 and the 2024 SH0ES measurement. Specifically, degeneracies with extended-model parameters do not align the P-ACT or P-ACT-LB limits with the SH0ES constraints, which indicates that the two measurements remain inconsistent. While the ACT DR6 measurement of H_0 falls within the range of the CCHP measurement, it is still below the latest SH0ES measurement, highlighting the ongoing tension between these results.
# No. The range of H_0 given by the models studied in the ACT DR6 paper is still lower than the 2024 SH0ES measurement of H_0.
# [0.9288339  1.         1.         0.80273349 0.95758462 1.
#  1.         0.81687718] 0.9382536482020541
#
# ['2_698 ± 0_016 k', 'cmb monopole temperature', 'cl ), according', 'p_act_lb dataset', 'confidence level', 'tcmb', '68']
# ['2_698 ± 0_016k']
# The CMB monopole temperature at the 68% confidence level (CL), according to the P-ACT-LB dataset, is TCMB = 2.698 ± 0.016 K.
# 2.698\pm0.016K
# [0.97913029] 0.9791302863477956
